# %%
import numpy as np
from sklearn.datasets import load_diabetes

# %%
X,y=load_diabetes(return_X_y=True)

# %%
X
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
X.shape
# Out:
# (442, 10)

# %%
y.shape
# Out:
# (442,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (353, 10)
# (89, 10)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
reg.intercept_
# Out:
# np.float64(151.88331005254167)

# %%
reg.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
##making our ownn multiple linear regression

# %%
class my_Multiple_linear_regression:
  def __init__(self):
    self.coef_=None
    self.intercept_=None
  def fit(self,X_train,y_train):
   X_train=np.insert(X_train,0,1,axis=1)

   #finding all betas by formula
   betas = np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)
   #seperating intercept and slopes
   self.intercept_ = betas[0]
   self.coef_ = betas[1:]

   print(betas);
  def predict(self,X_test):
    y_pred = np.dot(X_test,self.coef_) + self.intercept_
    return y_pred

# %%
X_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4239342174.py in <cell line: 0>()
# ----> 1 X_train
#
# NameError: name 'X_train' is not defined

# %%
mlr = my_Multiple_linear_regression()

# %%
mlr.fit(X_train,y_train)
# Out:
# [ 151.88331005   -9.15865318 -205.45432163  516.69374454  340.61999905
#  -895.5520019   561.22067904  153.89310954  126.73139688  861.12700152
#    52.42112238]

# %%
y= mlr.predict(X_test)

# %%
r2_score(y_test,mlr.predict(X_test))
# Out:
# 0.43993386615689634

# %%
mlr.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
mlr.intercept_
# Out:
# np.float64(151.88331005254165)

# %%
y
# Out:
# array([154.1213881 , 204.81835118, 124.93755353, 106.08950893,
#        258.5348576 , 256.3310074 , 118.75087616, 119.52440696,
#        101.50816735, 190.54048661, 141.70656811, 172.51883961,
#        174.33861649, 134.80942706, 294.13994537,  94.11798038,
#        211.97059795, 156.49579378, 134.21000428, 119.62664644,
#        148.87842251, 165.00873409, 151.10021038, 176.04063756,
#        133.27769647, 221.29555392, 197.17324941,  96.1577688 ,
#         50.26012711, 230.48580317, 242.06073866, 114.11129218,
#         67.07532417,  94.52943825, 201.21415375, 167.05136201,
#        159.881268  , 192.78746659, 114.49551325, 233.48234551,
#        140.82563045, 121.0680409 , 192.27480772, 191.12738845,
#        179.16865788, 148.34935601, 163.47414622, 276.81647884,
#        100.17926432, 164.10555298, 255.80762189, 136.9466204 ,
#        152.37503699, 107.92237882, 194.21924678,  77.34670792,
#        118.50482479,  68.38335763, 154.29258529, 162.48840259,
# ...

# %% [markdown]
# 1 is missing in the begaining of the matrix so we use a function of numpy function

# %% [markdown]
# KONSI ARRAY MAI, KONSE COLUMN INDEX PE, KYA VALUE,WHICH AXIS (1 FOR COLUMN AND 0 FOR ROW)

# %%
np.insert(X_train,0,1,axis=1)
# Out:
# array([[ 1.        , -0.00188202, -0.04464164, ..., -0.03949338,
#         -0.06291688,  0.04034337],
#        [ 1.        , -0.00914709, -0.04464164, ..., -0.03949338,
#          0.01703607, -0.0052198 ],
#        [ 1.        ,  0.02354575,  0.05068012, ..., -0.03949338,
#         -0.09643495, -0.01764613],
#        ...,
#        [ 1.        ,  0.06350368,  0.05068012, ..., -0.00259226,
#          0.08449153, -0.01764613],
#        [ 1.        , -0.05273755,  0.05068012, ...,  0.1081111 ,
#          0.03606033, -0.04249877],
#        [ 1.        ,  0.00175052,  0.05068012, ...,  0.1081111 ,
#          0.06898589,  0.12732762]])

# %%
np.insert(X_train,0,1,axis=1).shape
# Out:
# (353, 11)

# %%
X_train.shape
# Out:
# (353, 10)
