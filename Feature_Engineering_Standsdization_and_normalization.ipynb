# %%
import pandas as pd
import numpy as np

# %%
age_data = [23, 22, 24, 23, 21]
salary_data = [23000, 22000, 24000, 23000, 21000]

# %%
df=pd.DataFrame({'age':age_data,'salary':salary_data,'purchased':purchased_data})

# %%
display(df.columns)
# Out:
# Index(['age', 'salary', 'purchased'], dtype='object')

# %%
purchased_data = [True, False, True, False, True]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df[['age','salary']],df['purchased'],test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3066217873.py in <cell line: 0>()
# ----> 1 x_train_scaled=scaler.fit_transform(x_train)
#       2 x_test_scaled=scaler.transform(x_test)
#
# NameError: name 'scaler' is not defined

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler.fit(x_train)

x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled.mean()
# Out:
# np.float64(0.0)
